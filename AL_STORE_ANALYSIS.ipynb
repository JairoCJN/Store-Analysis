# %% [markdown]
# <a href="https://colab.research.google.com/github/JairoCJN/Store-Analysis/blob/main/AL_STORE_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Prueba")

# %% [markdown]
# ### Challenge
